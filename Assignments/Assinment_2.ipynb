# %% [markdown]
# # Assignment 2

# %% [markdown]
# **Please follow the instructions. Do not add new cell! Write your code in designated areas.**

# %%
                                                                                                                                                                                                                                                            import datetime
import socket
import pandas as pd
import numpy as np

# Get local time
local_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# Get computer ID or hostname
computer_id = socket.gethostname()

# Print output with local time and computer ID
print('Assignment 1 & 2: Solutions by Jack Romano') # Please change your name here
print('Local Time:', local_time)
print('Computer ID:', computer_id)
# Out:
# Assignment 1 & 2: Solutions by Jack Romano
# Local Time: 2024-02-09 03:24:28
# Computer ID: Denethor

# %% [markdown]
# ## NumPy

# %% [markdown]
# 1. Create a 2D numpy array of size 4x5 with random integers between 1 and 10. Find the maximum value of the entire array.

# %%
## Your code here down

array = np.random.randint(1, 11, size=(4, 5))
print(array)
# Find the maximum value in the array

print("\nMaximum value:", np.max(array))
## Your code here up
# Out:
# [[ 8  9  8  6  7]
#  [10  5 10  6  5]
#  [ 1  2 10  4  4]
#  [10  3  8  3  8]]
#
# Maximum value: 10

# %% [markdown]
# 2. Create a 1D numpy array of size 20 with random floats between 0 and 1. Reshape the array into a 4x5 matrix. Compute the mean of each row.

# %%
## Your code here down
array = np.random.random_sample((20,))
print(array)

array_45 = array.reshape((4, 5))
print(array_45)




## Your code here up
# Out:
# [0.51239664 0.25532198 0.56272661 0.13373973 0.55000425 0.75092071
#  0.29241776 0.38897961 0.90783238 0.06960855 0.38491567 0.67186253
#  0.87038479 0.57645795 0.84982499 0.08409567 0.07333779 0.83208861
#  0.68930106 0.81624965]
# [[0.51239664 0.25532198 0.56272661 0.13373973 0.55000425]
#  [0.75092071 0.29241776 0.38897961 0.90783238 0.06960855]
#  [0.38491567 0.67186253 0.87038479 0.57645795 0.84982499]
#  [0.08409567 0.07333779 0.83208861 0.68930106 0.81624965]]

# %% [markdown]
# 3. Create a 2D numpy array of size 5x5 with random integers between 1 and 100. Compute standard deviation of each column.

# %%
## Your code here down
array = np.random.randint(1, 101, size=(5, 5))

print(array)
# axis = 0 ensures columns are considered for standard deviation
print(array.std(axis=0))


## Your code here up
# Out:
# [[17 15 76 61 44]
#  [57 33 54 67 20]
#  [ 5 21 29 25  2]
#  [86 58  5 32 23]
#  [43 33 91 89 93]]
# [28.82776439 14.75127113 31.09340766 23.51510153 31.28322234]

# %% [markdown]
# 4. Create a 1D numpy array of size 15 with random floats between -10 and 10. Replace all negative values with their absolute values.

# %%
## Your code here down
array = np.random.randint(-10, 11, size=(15))
print(array)

array_abs = np.abs(array)
print(array_abs)

## Your code here up
# Out:
# [-1 -1 -3 -8  8 -4  1 -7 -2  2 -9 -3 -7 -1 -7]
# [1 1 3 8 8 4 1 7 2 2 9 3 7 1 7]

# %% [markdown]
# 5. Create a 2D numpy array of size 3x4 with random integers between 1 and 100. Calculate the sum of all elements in the array.

# %%
## Your code here down
array = np.random.randint(1, 101, size=(3, 4))
print(array)
print(np.sum(array))
## Your code here up
# Out:
# [[74 53  3 94]
#  [96 62 65 43]
#  [36 46 71 55]]
# 698

# %% [markdown]
# 7. Create a 2D numpy array of size 4x6 with random floats between 0 and 1. Normalize each column by subtracting the column mean and dividing by the column standard deviation.

# %%
## Your code here down
array = np.random.random_sample((4,6))
print(array)
# axis set to 0 for column mean and std
mean_arr = np.mean(array,axis = 0)
std_arr = np.std(array,axis = 0)

diff_array = np.subtract(array,mean_arr)

normalized_array = np.divide(diff_array,std_arr)

print(normalized_array)

## Your code here up
# Out:
# [[0.910725   0.55984944 0.74248909 0.95487388 0.79908528 0.00531113]
#  [0.50981828 0.01778005 0.10618344 0.74508922 0.92044825 0.62799982]
#  [0.42116095 0.37809249 0.62213459 0.87751823 0.01778167 0.14823613]
#  [0.24879315 0.84577582 0.87430996 0.86011663 0.86525483 0.66809589]]
# [[ 1.59756696  0.36456762  0.53647355  1.27268075  0.40348672 -1.22960307]
#  [-0.05271456 -1.4406022  -1.64879974 -1.52376454  0.73336704  0.91450435]
#  [-0.41766115 -0.24070941  0.12313841  0.24152422 -1.72019791 -0.73746865]
#  [-1.12719126  1.31674399  0.98918778  0.00955958  0.58334416  1.05256737]]

# %% [markdown]
# 8. Create a 2D numpy array of size 10x10 with random integers between 1 and 100. Replace all values greater than 50 with 1 and all other values with 0.

# %%
## Your code here down
array = np.random.randint(1, 101, size=(10, 10))
print(array)
array[array>50]=1
print(array)


## Your code here up
# Out:
# [[ 82  92  14   5  99  42  88  24  89  59]
#  [ 34  54  17  97  93  73  24  77  49  88]
#  [ 53  87  79  78  26  24 100  43  75  84]
#  [ 82  56  21  44  94  43  20  37  48  30]
#  [ 26  15  44  57  25  20  73  35   5  78]
#  [ 27  29  44  10  79   7  66  21  31  74]
#  [ 89  96  15  10  25  42  32  85  78  53]
#  [ 21  67  39  41  77  18  57  69  92  43]
#  [ 56  53  17  73  75  13   8  38  40  28]
#  [ 77   4  19  40  11  25  31  43  18  38]]
# [[ 1  1 14  5  1 42  1 24  1  1]
#  [34  1 17  1  1  1 24  1 49  1]
#  [ 1  1  1  1 26 24  1 43  1  1]
#  [ 1  1 21 44  1 43 20 37 48 30]
#  [26 15 44  1 25 20  1 35  5  1]
#  [27 29 44 10  1  7  1 21 31  1]
#  [ 1  1 15 10 25 42 32  1  1  1]
#  [21  1 39 41  1 18  1  1  1 43]
#  [ 1  1 17  1  1 13  8 38 40 28]
#  [ 1  4 19 40 11 25 31 43 18 38]]

# %% [markdown]
# 9. Create a 1D numpy array of size 50 with random floats between 0 and 1. Find the number of elements greater than 0.5.

# %%
## Your code here down
array = np.random.random_sample((50,))

count = np.sum(array > 0.5)
count
## Your code here up
# Out:
# 27

# %% [markdown]
# 10. Create a 2D numpy array of size 5x5 with random floats between -1 and 1. Find the absolute difference between the maximum and minimum values in each row.

# %%
## Your code here down
array = np.random.uniform(-1, 1, (5, 5))
print(array)
# axis 1 used for rows
delta_row = np.max(array, axis=1) - np.min(array, axis=1)
# Absolute value - isnt this redundant? max - min will always be positive, no?
delta_row = np.abs(delta_row)
print(delta_row)



## Your code here up
# Out:
# [[ 0.62099252  0.23721034 -0.47167601  0.70787215  0.52727412]
#  [ 0.09257141  0.47566759 -0.19406651  0.28056592  0.59957212]
#  [ 0.38265004  0.76966501 -0.96589212  0.99601817 -0.16018413]
#  [-0.54701319  0.55907845 -0.0321018   0.97597378  0.339751  ]
#  [ 0.61529342 -0.25646306 -0.38937606  0.83698798  0.4470245 ]]
# [1.17954816 0.79363863 1.9619103  1.52298696 1.22636404]

# %% [markdown]
# ## Pandas

# %% [markdown]
# Please refer the dataframe (farm data) we have created in the training. Please copy that cell and paste it below before starting this part.

# %%
import random
import pandas as pd

# Define the range for longitude and latitude
lon_range = (-105, -100)
lat_range = (50, 52)

# Define the list of soil types
soil_types = ['black', 'gray', 'dark brown', 'brown', None]

# Create an empty list to store the farms
farms = []

# Generate 40 farms
for i in range(1000):
    farm = {
        'farm_name': f'Farm {i+1}', # f is formated string
        'farm_lon': round(random.uniform(lon_range[0], lon_range[1]), 2), # random lon with 2 decimal points
        'farm_lat': round(random.uniform(lat_range[0], lat_range[1]), 2), # rantom lat with 2 decimal points
        'temperature': round(random.uniform(18, 33), 1), #random temp with 1 decimal points
        'precipitation': round(random.uniform(20, 90), 1), # random prec with 1 decimal points
        'soil_type': random.choice(soil_types) # random soil types from above list
    }
    farms.append(farm)

# %%
df = pd.DataFrame.from_dict(farms)
df.head()
# Out:
#   farm_name  farm_lon  farm_lat  temperature  precipitation   soil_type
# 0    Farm 1   -102.80     51.36         25.8           69.4       black
# 1    Farm 2   -102.75     50.52         22.0           85.8       brown
# 2    Farm 3   -103.32     50.29         27.0           25.3  dark brown
# 3    Farm 4   -103.83     51.85         30.6           54.3       brown
# 4    Farm 5   -104.05     50.67         27.7           77.2  dark brown

# %% [markdown]
# 1. Select the rows where the temperature is above 20 degrees Celsius.

# %%
## Your code here down

df_20=df[df['temperature']>20]
df_20.head()
## Your code here up
# Out:
#   farm_name  farm_lon  farm_lat  temperature  precipitation   soil_type
# 0    Farm 1   -102.80     51.36         25.8           69.4       black
# 1    Farm 2   -102.75     50.52         22.0           85.8       brown
# 2    Farm 3   -103.32     50.29         27.0           25.3  dark brown
# 3    Farm 4   -103.83     51.85         30.6           54.3       brown
# 4    Farm 5   -104.05     50.67         27.7           77.2  dark brown

# %% [markdown]
# 2. Sort the DataFrame by precipitation in descending order.

# %%
## Your code here down

df=df.sort_values(by=['precipitation'],ascending=False)
df.head()
## Your code here up
# Out:
#     farm_name  farm_lon  farm_lat  temperature  precipitation   soil_type
# 686  Farm 687   -100.92     50.47         32.5           90.0  dark brown
# 105  Farm 106   -100.90     50.09         27.5           90.0       black
# 936  Farm 937   -104.25     51.19         24.7           89.9        None
# 929  Farm 930   -100.71     51.67         28.6           89.9        gray
# 775  Farm 776   -102.95     51.75         28.8           89.9  dark brown

# %% [markdown]
# 3. Filter the DataFrame to include only the farms located within latitude (51.15 & 51.00) range.

# %%
## Your code here down

df51_5115 =df[(df['farm_lat']>=51.0)&(df['farm_lat']<=51.15)]
df51_5115.head()
## Your code here up
# Out:
#     farm_name  farm_lon  farm_lat  temperature  precipitation soil_type
# 327  Farm 328   -104.01     51.02         31.8           89.3      None
# 813  Farm 814   -104.97     51.02         18.6           87.5     black
# 638  Farm 639   -104.06     51.00         20.5           87.2      None
# 129  Farm 130   -104.45     51.00         31.4           86.5     black
# 312  Farm 313   -103.59     51.09         25.1           84.7      None

# %% [markdown]
#  4. Calculate the standard deviation of precipitation for each soil type.

# %%
## Your code here down
df.groupby(['soil_type'])['precipitation'].std()
## Your code here up
# Out:
# soil_type
# black         20.484735
# brown         19.051994
# dark brown    20.574443
# gray          20.937747
# Name: precipitation, dtype: float64

# %% [markdown]
# 5. Calculate the cumulative sum of precipitation for each soil type.

# %%
## Your code here down

df.groupby(['soil_type'])['precipitation'].cumsum().head()

## Your code here up
# Out:
# 686     90.0
# 105     90.0
# 936      NaN
# 929     89.9
# 775    179.9
# Name: precipitation, dtype: float64

# %% [markdown]
# 6. Determine the top 3 farms with the highest average temperature.

# %%
## Your code here down
df_top3temp=df.groupby(['farm_name'])['temperature'].mean().reset_index().sort_values(by=['temperature'],ascending=False).head(3)
df_top3temp

## Your code here up
# Out:
#     farm_name  temperature
# 913  Farm 920         33.0
# 735  Farm 760         33.0
# 722  Farm 749         33.0

# %% [markdown]
# 7. Find famrs in each soil type that have the highest temperature.

# %%
## Your code here down
df_soilmax=df.groupby(['soil_type'])['temperature'
].max().reset_index()
df_soilmax.head()

df_soilmax_out=df_soilmax.merge(df,how='inner',on=['temperature','soil_type'])
df_soilmax_out
## Your code here up
# Out:
#     soil_type  temperature farm_name  farm_lon  farm_lat  precipitation
# 0       black         32.8  Farm 782   -102.62     50.63           26.6
# 1       brown         32.9  Farm 845   -104.47     51.21           72.4
# 2       brown         32.9  Farm 483   -102.25     51.20           33.8
# 3  dark brown         33.0  Farm 749   -103.22     51.68           27.8
# 4        gray         33.0  Farm 920   -101.34     51.75           43.6
# 5        gray         33.0  Farm 443   -101.32     51.84           29.0
# 6        gray         33.0  Farm 760   -101.04     50.50           21.9

# %% [markdown]
# 8. Create new column 'percentage_tot_prec' and add the percentage contribution of each farm's precipitation (relative to total precipitation) to the column.

# %%
## Your code here down
total_precip = df['precipitation'].sum()
df['percentage_tot_prec'] = df['precipitation']/total_precip
df.head()
## Your code here up
# Out:
#     farm_name  farm_lon  farm_lat  temperature  precipitation   soil_type  \
# 686  Farm 687   -100.92     50.47         32.5           90.0  dark brown
# 105  Farm 106   -100.90     50.09         27.5           90.0       black
# 936  Farm 937   -104.25     51.19         24.7           89.9        None
# 929  Farm 930   -100.71     51.67         28.6           89.9        gray
# 775  Farm 776   -102.95     51.75         28.8           89.9  dark brown
#
#      percentage_tot_prec
# 686             0.001645
# 105             0.001645
# 936             0.001643
# 929             0.001643
# 775             0.001643

# %% [markdown]
# 9. Create a new column called "precipitation_rank" that ranks the farms based on their precipitation in ascending order, with ties being assigned the same rank.

# %%
## Your code here down
df['precipitation_rank'] = (df.sort_values(by=['precipitation'], ascending=[False])['precipitation']
                .rank(method='average', ascending=False)
             )
df.head()
## Your code here up
# Out:
#     farm_name  farm_lon  farm_lat  temperature  precipitation   soil_type  \
# 686  Farm 687   -100.92     50.47         32.5           90.0  dark brown
# 105  Farm 106   -100.90     50.09         27.5           90.0       black
# 936  Farm 937   -104.25     51.19         24.7           89.9        None
# 929  Farm 930   -100.71     51.67         28.6           89.9        gray
# 775  Farm 776   -102.95     51.75         28.8           89.9  dark brown
#
#      percentage_tot_prec  precipitation_rank
# 686             0.001645                 1.5
# 105             0.001645                 1.5
# 936             0.001643                 4.0
# 929             0.001643                 4.0
# 775             0.001643                 4.0

# %% [markdown]
# 10. Normalize the temperature column to a range between 0 and 1 for each farm.

# %%
## Your code here down
min_temp = df['temperature'].min()
max_temp = df['temperature'].max()
df['temp_normalize'] = (df['temperature'] - min_temp) / (max_temp - min_temp)
df.head()
## Your code here up
# Out:
#     farm_name  farm_lon  farm_lat  temperature  precipitation   soil_type  \
# 686  Farm 687   -100.92     50.47         32.5           90.0  dark brown
# 105  Farm 106   -100.90     50.09         27.5           90.0       black
# 936  Farm 937   -104.25     51.19         24.7           89.9        None
# 929  Farm 930   -100.71     51.67         28.6           89.9        gray
# 775  Farm 776   -102.95     51.75         28.8           89.9  dark brown
#
#      percentage_tot_prec  precipitation_rank  temp_normalize
# 686             0.001645                 1.5        0.966667
# 105             0.001645                 1.5        0.633333
# 936             0.001643                 4.0        0.446667
# 929             0.001643                 4.0        0.706667
# 775             0.001643                 4.0        0.720000

# %% [markdown]
# ## ETL

# %% [markdown]
# 11. Change column types accordingly.

# %%
## Your code here down

print(df.dtypes)
df['farm_name']=df['farm_name'].astype(str)
df['soil_type']=df['soil_type'].astype(str)
df['farm_lon'] = df['farm_lon'].astype(float)
df['farm_lat'] = df['farm_lat'].astype(float)
df['precipitation'] = df['precipitation'].astype(float)
df['percentage_tot_prec'] = df['percentage_tot_prec'].astype(float)
df['precipitation_rank'] = df['precipitation_rank'].astype(int)
df['temp_normalize'] = df['temp_normalize'].astype(float)
df.head()

## Your code here up
# Out:
# farm_name               object
# farm_lon               float64
# farm_lat               float64
# temperature            float64
# precipitation          float64
# soil_type               object
# percentage_tot_prec    float64
# precipitation_rank     float64
# temp_normalize         float64
# dtype: object
#     farm_name  farm_lon  farm_lat  temperature  precipitation   soil_type  \
# 686  Farm 687   -100.92     50.47         32.5           90.0  dark brown
# 105  Farm 106   -100.90     50.09         27.5           90.0       black
# 936  Farm 937   -104.25     51.19         24.7           89.9        None
# 929  Farm 930   -100.71     51.67         28.6           89.9        gray
# 775  Farm 776   -102.95     51.75         28.8           89.9  dark brown
#
#      percentage_tot_prec  precipitation_rank  temp_normalize
# 686             0.001645                   1        0.966667
# 105             0.001645                   1        0.633333
# 936             0.001643                   4        0.446667
# 929             0.001643                   4        0.706667
# 775             0.001643                   4        0.720000

# %%
df[df['soil_type']=='None'].shape
# Out:
# (211, 9)

# %% [markdown]
# ## EDA

# %% [markdown]
# 12. Find missing values and give information how would you handle them

# %%
## Your code here down

print(df.isnull().sum())
# No nulls
for index, row in df.iterrows():
    if row.str.contains("None").any():
        print(row)

#     fill any null values with 0    
df=df.fillna(0)
# Leave string/object values as none
## Your code here up
# Out:
# farm_name              0
# farm_lon               0
# farm_lat               0
# temperature            0
# precipitation          0
# soil_type              0
# percentage_tot_prec    0
# precipitation_rank     0
# temp_normalize         0
# dtype: int64
# farm_name              Farm 937
# farm_lon                -104.25
# farm_lat                  51.19
# temperature                24.7
# precipitation              89.9
# soil_type                  None
# percentage_tot_prec    0.001643
# precipitation_rank            4
# temp_normalize         0.446667
# Name: 936, dtype: object
# farm_name              Farm 328
# farm_lon                -104.01
# farm_lat                  51.02
# temperature                31.8
# precipitation              89.3
# soil_type                  None
# percentage_tot_prec    0.001632
# precipitation_rank           14
# temp_normalize             0.92
# Name: 327, dtype: object
# farm_name              Farm 414
# farm_lon                -103.69
# farm_lat                  50.34
# temperature                18.3
# precipitation              88.4
# soil_type                  None
# percentage_tot_prec    0.001616
# precipitation_rank           22
# temp_normalize             0.02
# Name: 413, dtype: object
# farm_name              Farm 639
# farm_lon                -104.06
# farm_lat                   51.0
# temperature                20.5
# precipitation              87.2
# soil_type                  None
# percentage_tot_prec    0.001594
# precipitation_rank           37
# temp_normalize         0.166667
# Name: 638, dtype: object
# farm_name              Farm 710
# farm_lon                -102.58
# farm_lat                  51.45
# temperature                21.8
# precipitation              87.1
# soil_type                  None
# percentage_tot_prec    0.001592
# precipitation_rank           39
# temp_normalize         0.253333
# Name: 709, dtype: object
# farm_name              Farm 210
# farm_lon                -104.72
# farm_lat                  50.09
# temperature                30.2
# precipitation              86.5
# soil_type                  None
# percentage_tot_prec    0.001581
# precipitation_rank           47
# temp_normalize         0.813333
# Name: 209, dtype: object
# farm_name              Farm 238
# farm_lon                -102.22
# farm_lat                  50.33
# temperature                29.2
# precipitation              86.1
# soil_type                  None
# percentage_tot_prec    0.001574
# precipitation_rank           52
# temp_normalize         0.746667
# Name: 237, dtype: object
# farm_name              Farm 336
# farm_lon                -102.64
# farm_lat                  50.15
# temperature                31.8
# precipitation              86.0
# soil_type                  None
# percentage_tot_prec    0.001572
# precipitation_rank           55
# temp_normalize             0.92
# Name: 335, dtype: object
# farm_name              Farm 340
# farm_lon                -104.54
# farm_lat                   50.6
# temperature                19.3
# precipitation              85.8
# soil_type                  None
# percentage_tot_prec    0.001568
# precipitation_rank           63
# temp_normalize         0.086667
# Name: 339, dtype: object
# farm_name              Farm 605
# farm_lon                -101.32
# farm_lat                  50.28
# temperature                30.9
# precipitation              85.4
# soil_type                  None
# percentage_tot_prec    0.001561
# precipitation_rank           70
# temp_normalize             0.86
# Name: 604, dtype: object
# farm_name              Farm 313
# farm_lon                -103.59
# farm_lat                  51.09
# temperature                25.1
# precipitation              84.7
# soil_type                  None
# percentage_tot_prec    0.001548
# precipitation_rank           75
# temp_normalize         0.473333
# Name: 312, dtype: object
# farm_name              Farm 883
# farm_lon                -100.46
# farm_lat                  50.32
# temperature                25.5
# precipitation              84.5
# soil_type                  None
# percentage_tot_prec    0.001544
# precipitation_rank           79
# temp_normalize              0.5
# Name: 882, dtype: object
# farm_name              Farm 259
# farm_lon                -104.82
# farm_lat                  50.79
# temperature                31.1
# precipitation              84.3
# soil_type                  None
# percentage_tot_prec    0.001541
# precipitation_rank           81
# temp_normalize         0.873333
# Name: 258, dtype: object
# farm_name               Farm 37
# farm_lon                -101.85
# farm_lat                  50.38
# temperature                20.0
# precipitation              83.9
# soil_type                  None
# percentage_tot_prec    0.001533
# precipitation_rank           86
# temp_normalize         0.133333
# Name: 36, dtype: object
# farm_name               Farm 22
# farm_lon                -101.44
# farm_lat                   51.4
# temperature                24.5
# precipitation              81.9
# soil_type                  None
# percentage_tot_prec    0.001497
# precipitation_rank          117
# temp_normalize         0.433333
# Name: 21, dtype: object
# farm_name              Farm 686
# farm_lon                -104.06
# farm_lat                  51.03
# temperature                19.1
# precipitation              81.8
# soil_type                  None
# percentage_tot_prec    0.001495
# precipitation_rank          120
# temp_normalize         0.073333
# Name: 685, dtype: object
# farm_name              Farm 501
# farm_lon                -101.68
# farm_lat                  50.94
# temperature                22.8
# precipitation              81.5
# soil_type                  None
# percentage_tot_prec     0.00149
# precipitation_rank          127
# temp_normalize             0.32
# Name: 500, dtype: object
# farm_name              Farm 745
# farm_lon                -100.82
# farm_lat                   51.9
# temperature                25.7
# precipitation              81.4
# soil_type                  None
# percentage_tot_prec    0.001488
# precipitation_rank          130
# temp_normalize         0.513333
# Name: 744, dtype: object
# farm_name              Farm 948
# farm_lon                -104.48
# farm_lat                  50.17
# temperature                31.4
# precipitation              81.3
# soil_type                  None
# percentage_tot_prec    0.001486
# precipitation_rank          131
# temp_normalize         0.893333
# Name: 947, dtype: object
# farm_name              Farm 826
# farm_lon                -104.27
# farm_lat                  51.82
# temperature                18.6
# precipitation              80.4
# soil_type                  None
# percentage_tot_prec     0.00147
# precipitation_rank          140
# temp_normalize             0.04
# Name: 825, dtype: object
# farm_name              Farm 791
# farm_lon                -104.65
# farm_lat                  50.27
# temperature                19.9
# precipitation              79.5
# soil_type                  None
# percentage_tot_prec    0.001453
# precipitation_rank          151
# temp_normalize         0.126667
# Name: 790, dtype: object
# farm_name              Farm 513
# farm_lon                -104.72
# farm_lat                  50.01
# temperature                20.4
# precipitation              79.5
# soil_type                  None
# percentage_tot_prec    0.001453
# precipitation_rank          151
# temp_normalize             0.16
# Name: 512, dtype: object
# farm_name              Farm 279
# farm_lon                -101.23
# farm_lat                   50.8
# temperature                30.3
# precipitation              79.4
# soil_type                  None
# percentage_tot_prec    0.001451
# precipitation_rank          154
# temp_normalize             0.82
# Name: 278, dtype: object
# farm_name              Farm 241
# farm_lon                -103.63
# farm_lat                  50.21
# temperature                23.2
# precipitation              79.2
# soil_type                  None
# percentage_tot_prec    0.001448
# precipitation_rank          156
# temp_normalize         0.346667
# Name: 240, dtype: object
# farm_name              Farm 202
# farm_lon                -102.09
# farm_lat                  51.25
# temperature                22.7
# precipitation              79.1
# soil_type                  None
# percentage_tot_prec    0.001446
# precipitation_rank          157
# temp_normalize         0.313333
# Name: 201, dtype: object
# farm_name              Farm 961
# farm_lon                 -100.4
# farm_lat                  50.68
# temperature                28.8
# precipitation              78.9
# soil_type                  None
# percentage_tot_prec    0.001442
# precipitation_rank          160
# temp_normalize             0.72
# Name: 960, dtype: object
# farm_name              Farm 901
# farm_lon                -102.48
# farm_lat                  51.55
# temperature                24.6
# precipitation              78.8
# soil_type                  None
# percentage_tot_prec     0.00144
# precipitation_rank          162
# temp_normalize             0.44
# Name: 900, dtype: object
# farm_name               Farm 59
# farm_lon                -102.35
# farm_lat                  51.85
# temperature                21.5
# precipitation              78.3
# soil_type                  None
# percentage_tot_prec    0.001431
# precipitation_rank          171
# temp_normalize         0.233333
# Name: 58, dtype: object
# farm_name              Farm 448
# farm_lon                -102.53
# farm_lat                  50.15
# temperature                26.1
# precipitation              77.8
# soil_type                  None
# percentage_tot_prec    0.001422
# precipitation_rank          176
# temp_normalize             0.54
# Name: 447, dtype: object
# farm_name              Farm 628
# farm_lon                 -103.4
# farm_lat                  51.79
# temperature                25.9
# precipitation              77.3
# soil_type                  None
# percentage_tot_prec    0.001413
# precipitation_rank          183
# temp_normalize         0.526667
# Name: 627, dtype: object
# farm_name              Farm 696
# farm_lon                -102.27
# farm_lat                  51.74
# temperature                18.6
# precipitation              76.9
# soil_type                  None
# percentage_tot_prec    0.001406
# precipitation_rank          188
# temp_normalize             0.04
# Name: 695, dtype: object
# farm_name              Farm 349
# farm_lon                -100.56
# farm_lat                  50.27
# temperature                22.5
# precipitation              76.6
# soil_type                  None
# percentage_tot_prec      0.0014
# precipitation_rank          190
# temp_normalize              0.3
# Name: 348, dtype: object
# farm_name              Farm 247
# farm_lon                -100.89
# farm_lat                  51.05
# temperature                30.6
# precipitation              76.2
# soil_type                  None
# percentage_tot_prec    0.001393
# precipitation_rank          194
# temp_normalize             0.84
# Name: 246, dtype: object
# farm_name              Farm 272
# farm_lon                -101.84
# farm_lat                   51.5
# temperature                26.1
# precipitation              75.7
# soil_type                  None
# percentage_tot_prec    0.001384
# precipitation_rank          201
# temp_normalize             0.54
# Name: 271, dtype: object
# farm_name              Farm 899
# farm_lon                -102.28
# farm_lat                  51.68
# temperature                32.4
# precipitation              75.7
# soil_type                  None
# percentage_tot_prec    0.001384
# precipitation_rank          201
# temp_normalize             0.96
# Name: 898, dtype: object
# farm_name              Farm 211
# farm_lon                -104.36
# farm_lat                  50.68
# temperature                26.3
# precipitation              75.6
# soil_type                  None
# percentage_tot_prec    0.001382
# precipitation_rank          204
# temp_normalize         0.553333
# Name: 210, dtype: object
# farm_name              Farm 441
# farm_lon                 -101.4
# farm_lat                  51.93
# temperature                20.7
# precipitation              75.1
# soil_type                  None
# percentage_tot_prec    0.001373
# precipitation_rank          211
# temp_normalize             0.18
# Name: 440, dtype: object
# farm_name              Farm 338
# farm_lon                -102.58
# farm_lat                   50.9
# temperature                18.6
# precipitation              75.1
# soil_type                  None
# percentage_tot_prec    0.001373
# precipitation_rank          211
# temp_normalize             0.04
# Name: 337, dtype: object
# farm_name              Farm 816
# farm_lon                -104.09
# farm_lat                  51.57
# temperature                24.8
# precipitation              75.0
# soil_type                  None
# percentage_tot_prec    0.001371
# precipitation_rank          214
# temp_normalize         0.453333
# Name: 815, dtype: object
# farm_name              Farm 240
# farm_lon                -102.27
# farm_lat                  51.56
# temperature                31.9
# precipitation              75.0
# soil_type                  None
# percentage_tot_prec    0.001371
# precipitation_rank          214
# temp_normalize         0.926667
# Name: 239, dtype: object
# farm_name              Farm 388
# farm_lon                -104.92
# farm_lat                  50.57
# temperature                19.7
# precipitation              74.9
# soil_type                  None
# percentage_tot_prec    0.001369
# precipitation_rank          217
# temp_normalize         0.113333
# Name: 387, dtype: object
# farm_name              Farm 843
# farm_lon                -102.81
# farm_lat                  51.52
# temperature                25.5
# precipitation              73.9
# soil_type                  None
# percentage_tot_prec    0.001351
# precipitation_rank          227
# temp_normalize              0.5
# Name: 842, dtype: object
# farm_name              Farm 413
# farm_lon                -104.61
# farm_lat                  51.79
# temperature                27.0
# precipitation              73.5
# soil_type                  None
# percentage_tot_prec    0.001343
# precipitation_rank          230
# temp_normalize              0.6
# Name: 412, dtype: object
# farm_name              Farm 641
# farm_lon                -101.69
# farm_lat                  50.93
# temperature                19.8
# precipitation              73.2
# soil_type                  None
# percentage_tot_prec    0.001338
# precipitation_rank          233
# temp_normalize             0.12
# Name: 640, dtype: object
# farm_name              Farm 787
# farm_lon                -104.69
# farm_lat                  51.69
# temperature                29.8
# precipitation              73.0
# soil_type                  None
# percentage_tot_prec    0.001334
# precipitation_rank          235
# temp_normalize         0.786667
# Name: 786, dtype: object
# farm_name              Farm 180
# farm_lon                -102.56
# farm_lat                   52.0
# temperature                28.4
# precipitation              73.0
# soil_type                  None
# percentage_tot_prec    0.001334
# precipitation_rank          235
# temp_normalize         0.693333
# Name: 179, dtype: object
# farm_name              Farm 329
# farm_lon                -103.87
# farm_lat                  51.62
# temperature                26.5
# precipitation              72.9
# soil_type                  None
# percentage_tot_prec    0.001332
# precipitation_rank          238
# temp_normalize         0.566667
# Name: 328, dtype: object
# farm_name              Farm 660
# farm_lon                -101.02
# farm_lat                  51.53
# temperature                21.6
# precipitation              72.8
# soil_type                  None
# percentage_tot_prec    0.001331
# precipitation_rank          240
# temp_normalize             0.24
# Name: 659, dtype: object
# farm_name              Farm 283
# farm_lon                -100.12
# farm_lat                   51.1
# temperature                31.1
# precipitation              72.2
# soil_type                  None
# percentage_tot_prec     0.00132
# precipitation_rank          251
# temp_normalize         0.873333
# Name: 282, dtype: object
# farm_name              Farm 894
# farm_lon                -101.97
# farm_lat                  50.58
# temperature                25.3
# precipitation              71.7
# soil_type                  None
# percentage_tot_prec    0.001311
# precipitation_rank          252
# temp_normalize         0.486667
# Name: 893, dtype: object
# farm_name              Farm 680
# farm_lon                -102.03
# farm_lat                  51.45
# temperature                22.2
# precipitation              71.3
# soil_type                  None
# percentage_tot_prec    0.001303
# precipitation_rank          256
# temp_normalize             0.28
# Name: 679, dtype: object
# farm_name              Farm 392
# farm_lon                 -100.7
# farm_lat                  50.08
# temperature                21.9
# precipitation              71.3
# soil_type                  None
# percentage_tot_prec    0.001303
# precipitation_rank          256
# temp_normalize             0.26
# Name: 391, dtype: object
# farm_name              Farm 387
# farm_lon                -103.23
# farm_lat                  50.91
# temperature                25.3
# precipitation              71.3
# soil_type                  None
# percentage_tot_prec    0.001303
# precipitation_rank          256
# temp_normalize         0.486667
# Name: 386, dtype: object
# farm_name              Farm 298
# farm_lon                -103.08
# farm_lat                  50.98
# temperature                29.2
# precipitation              71.0
# soil_type                  None
# percentage_tot_prec    0.001298
# precipitation_rank          262
# temp_normalize         0.746667
# Name: 297, dtype: object
# farm_name              Farm 289
# farm_lon                -104.32
# farm_lat                  51.99
# temperature                26.1
# precipitation              70.6
# soil_type                  None
# percentage_tot_prec     0.00129
# precipitation_rank          267
# temp_normalize             0.54
# Name: 288, dtype: object
# farm_name              Farm 450
# farm_lon                -101.67
# farm_lat                  51.69
# temperature                25.3
# precipitation              70.5
# soil_type                  None
# percentage_tot_prec    0.001289
# precipitation_rank          269
# temp_normalize         0.486667
# Name: 449, dtype: object
# farm_name              Farm 888
# farm_lon                 -101.1
# farm_lat                  51.34
# temperature                26.1
# precipitation              70.1
# soil_type                  None
# percentage_tot_prec    0.001281
# precipitation_rank          274
# temp_normalize             0.54
# Name: 887, dtype: object
# farm_name              Farm 207
# farm_lon                -104.37
# farm_lat                  51.98
# temperature                20.7
# precipitation              70.0
# soil_type                  None
# percentage_tot_prec    0.001279
# precipitation_rank          276
# temp_normalize             0.18
# Name: 206, dtype: object
# farm_name              Farm 181
# farm_lon                -104.94
# farm_lat                  50.15
# temperature                19.5
# precipitation              69.9
# soil_type                  None
# percentage_tot_prec    0.001278
# precipitation_rank          280
# temp_normalize              0.1
# Name: 180, dtype: object
# farm_name              Farm 221
# farm_lon                -100.89
# farm_lat                   50.1
# temperature                32.6
# precipitation              69.9
# soil_type                  None
# percentage_tot_prec    0.001278
# precipitation_rank          280
# temp_normalize         0.973333
# Name: 220, dtype: object
# farm_name              Farm 846
# farm_lon                -100.77
# farm_lat                  50.93
# temperature                30.3
# precipitation              69.4
# soil_type                  None
# percentage_tot_prec    0.001268
# precipitation_rank          290
# temp_normalize             0.82
# Name: 845, dtype: object
# farm_name              Farm 363
# farm_lon                 -100.5
# farm_lat                  50.44
# temperature                28.1
# precipitation              69.4
# soil_type                  None
# percentage_tot_prec    0.001268
# precipitation_rank          290
# temp_normalize         0.673333
# Name: 362, dtype: object
# farm_name              Farm 352
# farm_lon                -104.98
# farm_lat                  50.57
# temperature                31.3
# precipitation              69.3
# soil_type                  None
# percentage_tot_prec    0.001267
# precipitation_rank          294
# temp_normalize         0.886667
# Name: 351, dtype: object
# farm_name              Farm 571
# farm_lon                -102.16
# farm_lat                  50.22
# temperature                24.9
# precipitation              69.1
# soil_type                  None
# percentage_tot_prec    0.001263
# precipitation_rank          296
# temp_normalize             0.46
# Name: 570, dtype: object
# farm_name              Farm 985
# farm_lon                -103.12
# farm_lat                  51.07
# temperature                26.0
# precipitation              68.7
# soil_type                  None
# percentage_tot_prec    0.001256
# precipitation_rank          299
# temp_normalize         0.533333
# Name: 984, dtype: object
# farm_name              Farm 133
# farm_lon                -100.62
# farm_lat                  51.38
# temperature                22.8
# precipitation              68.1
# soil_type                  None
# percentage_tot_prec    0.001245
# precipitation_rank          308
# temp_normalize             0.32
# Name: 132, dtype: object
# farm_name               Farm 40
# farm_lon                -102.84
# farm_lat                  51.96
# temperature                20.4
# precipitation              67.9
# soil_type                  None
# percentage_tot_prec    0.001241
# precipitation_rank          310
# temp_normalize             0.16
# Name: 39, dtype: object
# farm_name              Farm 341
# farm_lon                -100.12
# farm_lat                  50.05
# temperature                29.1
# precipitation              67.6
# soil_type                  None
# percentage_tot_prec    0.001236
# precipitation_rank          313
# temp_normalize             0.74
# Name: 340, dtype: object
# farm_name              Farm 422
# farm_lon                -104.51
# farm_lat                   51.8
# temperature                30.4
# precipitation              67.4
# soil_type                  None
# percentage_tot_prec    0.001232
# precipitation_rank          316
# temp_normalize         0.826667
# Name: 421, dtype: object
# farm_name              Farm 623
# farm_lon                -101.33
# farm_lat                  50.18
# temperature                28.6
# precipitation              67.1
# soil_type                  None
# percentage_tot_prec    0.001226
# precipitation_rank          320
# temp_normalize         0.706667
# Name: 622, dtype: object
# farm_name              Farm 103
# farm_lon                -102.92
# farm_lat                  51.46
# temperature                23.7
# precipitation              66.8
# soil_type                  None
# percentage_tot_prec    0.001221
# precipitation_rank          326
# temp_normalize             0.38
# Name: 102, dtype: object
# farm_name              Farm 732
# farm_lon                -100.05
# farm_lat                  51.24
# temperature                25.4
# precipitation              66.0
# soil_type                  None
# percentage_tot_prec    0.001206
# precipitation_rank          333
# temp_normalize         0.493333
# Name: 731, dtype: object
# farm_name              Farm 841
# farm_lon                -103.84
# farm_lat                  51.39
# temperature                20.2
# precipitation              65.6
# soil_type                  None
# percentage_tot_prec    0.001199
# precipitation_rank          338
# temp_normalize         0.146667
# Name: 840, dtype: object
# farm_name              Farm 490
# farm_lon                -101.53
# farm_lat                  50.19
# temperature                23.0
# precipitation              65.1
# soil_type                  None
# percentage_tot_prec     0.00119
# precipitation_rank          343
# temp_normalize         0.333333
# Name: 489, dtype: object
# farm_name              Farm 480
# farm_lon                 -100.4
# farm_lat                  51.44
# temperature                18.7
# precipitation              64.2
# soil_type                  None
# percentage_tot_prec    0.001173
# precipitation_rank          353
# temp_normalize         0.046667
# Name: 479, dtype: object
# farm_name              Farm 802
# farm_lon                -103.33
# farm_lat                  51.72
# temperature                29.0
# precipitation              63.8
# soil_type                  None
# percentage_tot_prec    0.001166
# precipitation_rank          358
# temp_normalize         0.733333
# Name: 801, dtype: object
# farm_name              Farm 786
# farm_lon                -100.98
# farm_lat                  50.07
# temperature                29.9
# precipitation              63.4
# soil_type                  None
# percentage_tot_prec    0.001159
# precipitation_rank          366
# temp_normalize         0.793333
# Name: 785, dtype: object
# farm_name              Farm 757
# farm_lon                -101.68
# farm_lat                  50.75
# temperature                31.6
# precipitation              63.0
# soil_type                  None
# percentage_tot_prec    0.001151
# precipitation_rank          375
# temp_normalize         0.906667
# Name: 756, dtype: object
# farm_name              Farm 108
# farm_lon                -100.97
# farm_lat                  50.86
# temperature                32.5
# precipitation              62.9
# soil_type                  None
# percentage_tot_prec     0.00115
# precipitation_rank          377
# temp_normalize         0.966667
# Name: 107, dtype: object
# farm_name              Farm 770
# farm_lon                -103.23
# farm_lat                  51.99
# temperature                19.9
# precipitation              62.2
# soil_type                  None
# percentage_tot_prec    0.001137
# precipitation_rank          384
# temp_normalize         0.126667
# Name: 769, dtype: object
# farm_name              Farm 485
# farm_lon                -103.37
# farm_lat                   51.9
# temperature                26.6
# precipitation              62.1
# soil_type                  None
# percentage_tot_prec    0.001135
# precipitation_rank          385
# temp_normalize         0.573333
# Name: 484, dtype: object
# farm_name               Farm 42
# farm_lon                 -103.0
# farm_lat                   51.2
# temperature                21.4
# precipitation              61.8
# soil_type                  None
# percentage_tot_prec     0.00113
# precipitation_rank          390
# temp_normalize         0.226667
# Name: 41, dtype: object
# farm_name              Farm 965
# farm_lon                -100.78
# farm_lat                   51.8
# temperature                21.9
# precipitation              61.8
# soil_type                  None
# percentage_tot_prec     0.00113
# precipitation_rank          390
# temp_normalize             0.26
# Name: 964, dtype: object
# farm_name              Farm 663
# farm_lon                -101.28
# farm_lat                  50.45
# temperature                26.2
# precipitation              61.8
# soil_type                  None
# percentage_tot_prec     0.00113
# precipitation_rank          390
# temp_normalize         0.546667
# Name: 662, dtype: object
# farm_name              Farm 408
# farm_lon                -104.78
# farm_lat                  51.61
# temperature                21.6
# precipitation              61.5
# soil_type                  None
# percentage_tot_prec    0.001124
# precipitation_rank          394
# temp_normalize             0.24
# Name: 407, dtype: object
# farm_name              Farm 945
# farm_lon                -104.35
# farm_lat                  51.24
# temperature                29.3
# precipitation              61.3
# soil_type                  None
# percentage_tot_prec     0.00112
# precipitation_rank          397
# temp_normalize         0.753333
# Name: 944, dtype: object
# farm_name              Farm 265
# farm_lon                -103.17
# farm_lat                  50.99
# temperature                24.4
# precipitation              61.3
# soil_type                  None
# percentage_tot_prec     0.00112
# precipitation_rank          397
# temp_normalize         0.426667
# Name: 264, dtype: object
# farm_name              Farm 288
# farm_lon                -100.91
# farm_lat                  51.79
# temperature                32.7
# precipitation              61.2
# soil_type                  None
# percentage_tot_prec    0.001119
# precipitation_rank          400
# temp_normalize             0.98
# Name: 287, dtype: object
# farm_name              Farm 557
# farm_lon                -101.54
# farm_lat                   51.1
# temperature                32.3
# precipitation              61.2
# soil_type                  None
# percentage_tot_prec    0.001119
# precipitation_rank          400
# temp_normalize         0.953333
# Name: 556, dtype: object
# farm_name              Farm 925
# farm_lon                -104.05
# farm_lat                  51.65
# temperature                29.2
# precipitation              60.8
# soil_type                  None
# percentage_tot_prec    0.001111
# precipitation_rank          402
# temp_normalize         0.746667
# Name: 924, dtype: object
# farm_name              Farm 583
# farm_lon                -104.09
# farm_lat                   50.7
# temperature                25.6
# precipitation              60.7
# soil_type                  None
# percentage_tot_prec    0.001109
# precipitation_rank          403
# temp_normalize         0.506667
# Name: 582, dtype: object
# farm_name              Farm 325
# farm_lon                -100.35
# farm_lat                  50.03
# temperature                21.0
# precipitation              60.4
# soil_type                  None
# percentage_tot_prec    0.001104
# precipitation_rank          405
# temp_normalize              0.2
# Name: 324, dtype: object
# farm_name              Farm 877
# farm_lon                -104.29
# farm_lat                  50.66
# temperature                31.1
# precipitation              60.2
# soil_type                  None
# percentage_tot_prec      0.0011
# precipitation_rank          407
# temp_normalize         0.873333
# Name: 876, dtype: object
# farm_name              Farm 804
# farm_lon                -100.71
# farm_lat                  51.91
# temperature                18.5
# precipitation              60.0
# soil_type                  None
# percentage_tot_prec    0.001097
# precipitation_rank          411
# temp_normalize         0.033333
# Name: 803, dtype: object
# farm_name               Farm 60
# farm_lon                -104.98
# farm_lat                  51.67
# temperature                32.8
# precipitation              59.5
# soil_type                  None
# percentage_tot_prec    0.001088
# precipitation_rank          418
# temp_normalize         0.986667
# Name: 59, dtype: object
# farm_name               Farm 62
# farm_lon                -100.72
# farm_lat                  50.62
# temperature                27.8
# precipitation              59.4
# soil_type                  None
# percentage_tot_prec    0.001086
# precipitation_rank          420
# temp_normalize         0.653333
# Name: 61, dtype: object
# farm_name              Farm 892
# farm_lon                -101.38
# farm_lat                  51.46
# temperature                23.1
# precipitation              58.9
# soil_type                  None
# percentage_tot_prec    0.001077
# precipitation_rank          422
# temp_normalize             0.34
# Name: 891, dtype: object
# farm_name              Farm 688
# farm_lon                -100.91
# farm_lat                  51.24
# temperature                21.1
# precipitation              58.3
# soil_type                  None
# percentage_tot_prec    0.001066
# precipitation_rank          430
# temp_normalize         0.206667
# Name: 687, dtype: object
# farm_name              Farm 530
# farm_lon                -100.53
# farm_lat                  51.09
# temperature                28.6
# precipitation              58.1
# soil_type                  None
# percentage_tot_prec    0.001062
# precipitation_rank          432
# temp_normalize         0.706667
# Name: 529, dtype: object
# farm_name              Farm 122
# farm_lon                -104.64
# farm_lat                  51.83
# temperature                21.9
# precipitation              57.5
# soil_type                  None
# percentage_tot_prec    0.001051
# precipitation_rank          441
# temp_normalize             0.26
# Name: 121, dtype: object
# farm_name              Farm 376
# farm_lon                -102.91
# farm_lat                  51.77
# temperature                30.3
# precipitation              57.2
# soil_type                  None
# percentage_tot_prec    0.001045
# precipitation_rank          443
# temp_normalize             0.82
# Name: 375, dtype: object
# farm_name              Farm 742
# farm_lon                -102.06
# farm_lat                  50.14
# temperature                32.3
# precipitation              56.8
# soil_type                  None
# percentage_tot_prec    0.001038
# precipitation_rank          447
# temp_normalize         0.953333
# Name: 741, dtype: object
# farm_name              Farm 144
# farm_lon                -103.77
# farm_lat                  50.08
# temperature                31.5
# precipitation              56.8
# soil_type                  None
# percentage_tot_prec    0.001038
# precipitation_rank          447
# temp_normalize              0.9
# Name: 143, dtype: object
# farm_name              Farm 473
# farm_lon                -100.49
# farm_lat                  50.89
# temperature                20.2
# precipitation              56.7
# soil_type                  None
# percentage_tot_prec    0.001036
# precipitation_rank          449
# temp_normalize         0.146667
# Name: 472, dtype: object
# farm_name              Farm 429
# farm_lon                -100.96
# farm_lat                  51.89
# temperature                32.7
# precipitation              56.2
# soil_type                  None
# percentage_tot_prec    0.001027
# precipitation_rank          455
# temp_normalize             0.98
# Name: 428, dtype: object
# farm_name              Farm 322
# farm_lon                -101.73
# farm_lat                  50.84
# temperature                19.8
# precipitation              55.7
# soil_type                  None
# percentage_tot_prec    0.001018
# precipitation_rank          467
# temp_normalize             0.12
# Name: 321, dtype: object
# farm_name              Farm 331
# farm_lon                -102.34
# farm_lat                  50.98
# temperature                22.2
# precipitation              55.7
# soil_type                  None
# percentage_tot_prec    0.001018
# precipitation_rank          467
# temp_normalize             0.28
# Name: 330, dtype: object
# farm_name              Farm 531
# farm_lon                -102.91
# farm_lat                  50.27
# temperature                27.0
# precipitation              53.9
# soil_type                  None
# percentage_tot_prec    0.000985
# precipitation_rank          493
# temp_normalize              0.6
# Name: 530, dtype: object
# farm_name              Farm 751
# farm_lon                -103.27
# farm_lat                  50.92
# temperature                27.6
# precipitation              53.4
# soil_type                  None
# percentage_tot_prec    0.000976
# precipitation_rank          498
# temp_normalize             0.64
# Name: 750, dtype: object
# farm_name              Farm 449
# farm_lon                 -103.6
# farm_lat                  50.99
# temperature                21.4
# precipitation              53.1
# soil_type                  None
# percentage_tot_prec    0.000971
# precipitation_rank          501
# temp_normalize         0.226667
# Name: 448, dtype: object
# farm_name              Farm 553
# farm_lon                -103.09
# farm_lat                  51.78
# temperature                25.4
# precipitation              53.0
# soil_type                  None
# percentage_tot_prec    0.000969
# precipitation_rank          505
# temp_normalize         0.493333
# Name: 552, dtype: object
# farm_name              Farm 107
# farm_lon                -102.82
# farm_lat                  51.77
# temperature                32.1
# precipitation              52.6
# soil_type                  None
# percentage_tot_prec    0.000961
# precipitation_rank          512
# temp_normalize             0.94
# Name: 106, dtype: object
# farm_name              Farm 962
# farm_lon                 -101.7
# farm_lat                   50.3
# temperature                29.2
# precipitation              52.1
# soil_type                  None
# percentage_tot_prec    0.000952
# precipitation_rank          520
# temp_normalize         0.746667
# Name: 961, dtype: object
# farm_name              Farm 434
# farm_lon                -103.96
# farm_lat                  50.85
# temperature                19.7
# precipitation              52.0
# soil_type                  None
# percentage_tot_prec     0.00095
# precipitation_rank          522
# temp_normalize         0.113333
# Name: 433, dtype: object
# farm_name              Farm 726
# farm_lon                -100.03
# farm_lat                  50.17
# temperature                28.9
# precipitation              51.9
# soil_type                  None
# percentage_tot_prec    0.000949
# precipitation_rank          524
# temp_normalize         0.726667
# Name: 725, dtype: object
# farm_name              Farm 223
# farm_lon                -102.39
# farm_lat                  50.62
# temperature                24.7
# precipitation              51.5
# soil_type                  None
# percentage_tot_prec    0.000941
# precipitation_rank          532
# temp_normalize         0.446667
# Name: 222, dtype: object
# farm_name              Farm 737
# farm_lon                -102.06
# farm_lat                  51.14
# temperature                19.9
# precipitation              51.3
# soil_type                  None
# percentage_tot_prec    0.000938
# precipitation_rank          535
# temp_normalize         0.126667
# Name: 736, dtype: object
# farm_name               Farm 16
# farm_lon                -100.38
# farm_lat                  50.94
# temperature                23.0
# precipitation              50.9
# soil_type                  None
# percentage_tot_prec     0.00093
# precipitation_rank          544
# temp_normalize         0.333333
# Name: 15, dtype: object
# farm_name              Farm 556
# farm_lon                -104.84
# farm_lat                  51.47
# temperature                24.6
# precipitation              50.6
# soil_type                  None
# percentage_tot_prec    0.000925
# precipitation_rank          548
# temp_normalize             0.44
# Name: 555, dtype: object
# farm_name              Farm 208
# farm_lon                -104.86
# farm_lat                  50.06
# temperature                19.3
# precipitation              50.5
# soil_type                  None
# percentage_tot_prec    0.000923
# precipitation_rank          549
# temp_normalize         0.086667
# Name: 207, dtype: object
# farm_name              Farm 520
# farm_lon                -103.94
# farm_lat                  50.71
# temperature                32.7
# precipitation              50.3
# soil_type                  None
# percentage_tot_prec    0.000919
# precipitation_rank          552
# temp_normalize             0.98
# Name: 519, dtype: object
# farm_name              Farm 960
# farm_lon                -103.38
# farm_lat                  50.97
# temperature                25.9
# precipitation              50.3
# soil_type                  None
# percentage_tot_prec    0.000919
# precipitation_rank          552
# temp_normalize         0.526667
# Name: 959, dtype: object
# farm_name              Farm 715
# farm_lon                 -102.1
# farm_lat                  50.28
# temperature                24.4
# precipitation              50.2
# soil_type                  None
# percentage_tot_prec    0.000918
# precipitation_rank          554
# temp_normalize         0.426667
# Name: 714, dtype: object
# farm_name              Farm 909
# farm_lon                -102.08
# farm_lat                  50.13
# temperature                26.2
# precipitation              50.1
# soil_type                  None
# percentage_tot_prec    0.000916
# precipitation_rank          556
# temp_normalize         0.546667
# Name: 908, dtype: object
# farm_name              Farm 222
# farm_lon                -100.63
# farm_lat                  51.87
# temperature                25.6
# precipitation              49.5
# soil_type                  None
# percentage_tot_prec    0.000905
# precipitation_rank          562
# temp_normalize         0.506667
# Name: 221, dtype: object
# farm_name              Farm 719
# farm_lon                -102.13
# farm_lat                  51.66
# temperature                22.8
# precipitation              49.3
# soil_type                  None
# percentage_tot_prec    0.000901
# precipitation_rank          568
# temp_normalize             0.32
# Name: 718, dtype: object
# farm_name              Farm 409
# farm_lon                -104.95
# farm_lat                  51.08
# temperature                19.6
# precipitation              49.3
# soil_type                  None
# percentage_tot_prec    0.000901
# precipitation_rank          568
# temp_normalize         0.106667
# Name: 408, dtype: object
# farm_name              Farm 380
# farm_lon                -100.38
# farm_lat                  50.44
# temperature                18.2
# precipitation              48.0
# soil_type                  None
# percentage_tot_prec    0.000877
# precipitation_rank          599
# temp_normalize         0.013333
# Name: 379, dtype: object
# farm_name              Farm 105
# farm_lon                -104.02
# farm_lat                  51.62
# temperature                28.4
# precipitation              48.0
# soil_type                  None
# percentage_tot_prec    0.000877
# precipitation_rank          599
# temp_normalize         0.693333
# Name: 104, dtype: object
# farm_name               Farm 11
# farm_lon                -102.05
# farm_lat                   51.7
# temperature                28.3
# precipitation              48.0
# soil_type                  None
# percentage_tot_prec    0.000877
# precipitation_rank          599
# temp_normalize         0.686667
# Name: 10, dtype: object
# farm_name              Farm 173
# farm_lon                -101.89
# farm_lat                  51.24
# temperature                26.5
# precipitation              47.8
# soil_type                  None
# percentage_tot_prec    0.000874
# precipitation_rank          604
# temp_normalize         0.566667
# Name: 172, dtype: object
# farm_name              Farm 503
# farm_lon                -101.03
# farm_lat                  51.88
# temperature                22.3
# precipitation              47.7
# soil_type                  None
# percentage_tot_prec    0.000872
# precipitation_rank          607
# temp_normalize         0.286667
# Name: 502, dtype: object
# farm_name              Farm 438
# farm_lon                -104.17
# farm_lat                  50.21
# temperature                26.9
# precipitation              47.2
# soil_type                  None
# percentage_tot_prec    0.000863
# precipitation_rank          614
# temp_normalize         0.593333
# Name: 437, dtype: object
# farm_name              Farm 150
# farm_lon                -100.21
# farm_lat                  51.61
# temperature                24.5
# precipitation              46.1
# soil_type                  None
# percentage_tot_prec    0.000843
# precipitation_rank          628
# temp_normalize         0.433333
# Name: 149, dtype: object
# farm_name              Farm 683
# farm_lon                -103.37
# farm_lat                   50.0
# temperature                22.6
# precipitation              45.7
# soil_type                  None
# percentage_tot_prec    0.000835
# precipitation_rank          635
# temp_normalize         0.306667
# Name: 682, dtype: object
# farm_name              Farm 137
# farm_lon                -101.54
# farm_lat                  51.49
# temperature                19.4
# precipitation              45.7
# soil_type                  None
# percentage_tot_prec    0.000835
# precipitation_rank          635
# temp_normalize         0.093333
# Name: 136, dtype: object
# farm_name              Farm 365
# farm_lon                -102.69
# farm_lat                  51.96
# temperature                22.1
# precipitation              45.3
# soil_type                  None
# percentage_tot_prec    0.000828
# precipitation_rank          640
# temp_normalize         0.273333
# Name: 364, dtype: object
# farm_name               Farm 99
# farm_lon                -100.59
# farm_lat                  51.58
# temperature                23.0
# precipitation              45.3
# soil_type                  None
# percentage_tot_prec    0.000828
# precipitation_rank          640
# temp_normalize         0.333333
# Name: 98, dtype: object
# farm_name              Farm 262
# farm_lon                -102.54
# farm_lat                   51.6
# temperature                20.2
# precipitation              45.1
# soil_type                  None
# percentage_tot_prec    0.000824
# precipitation_rank          642
# temp_normalize         0.146667
# Name: 261, dtype: object
# farm_name              Farm 523
# farm_lon                -104.09
# farm_lat                  51.05
# temperature                22.1
# precipitation              45.0
# soil_type                  None
# percentage_tot_prec    0.000822
# precipitation_rank          645
# temp_normalize         0.273333
# Name: 522, dtype: object
# farm_name              Farm 823
# farm_lon                -103.42
# farm_lat                  51.17
# temperature                20.3
# precipitation              44.7
# soil_type                  None
# percentage_tot_prec    0.000817
# precipitation_rank          649
# temp_normalize         0.153333
# Name: 822, dtype: object
# farm_name              Farm 120
# farm_lon                -104.26
# farm_lat                  51.86
# temperature                32.9
# precipitation              44.7
# soil_type                  None
# percentage_tot_prec    0.000817
# precipitation_rank          649
# temp_normalize         0.993333
# Name: 119, dtype: object
# farm_name              Farm 284
# farm_lon                -102.11
# farm_lat                  50.06
# temperature                31.8
# precipitation              43.9
# soil_type                  None
# percentage_tot_prec    0.000802
# precipitation_rank          657
# temp_normalize             0.92
# Name: 283, dtype: object
# farm_name              Farm 555
# farm_lon                -102.11
# farm_lat                  51.66
# temperature                32.2
# precipitation              43.8
# soil_type                  None
# percentage_tot_prec    0.000801
# precipitation_rank          661
# temp_normalize         0.946667
# Name: 554, dtype: object
# farm_name              Farm 767
# farm_lon                -102.37
# farm_lat                  50.69
# temperature                18.1
# precipitation              43.2
# soil_type                  None
# percentage_tot_prec     0.00079
# precipitation_rank          670
# temp_normalize         0.006667
# Name: 766, dtype: object
# farm_name              Farm 781
# farm_lon                -102.09
# farm_lat                  50.22
# temperature                32.1
# precipitation              43.1
# soil_type                  None
# percentage_tot_prec    0.000788
# precipitation_rank          674
# temp_normalize             0.94
# Name: 780, dtype: object
# farm_name              Farm 512
# farm_lon                 -101.4
# farm_lat                  51.82
# temperature                22.8
# precipitation              42.8
# soil_type                  None
# percentage_tot_prec    0.000782
# precipitation_rank          680
# temp_normalize             0.32
# Name: 511, dtype: object
# farm_name              Farm 998
# farm_lon                -100.56
# farm_lat                  51.72
# temperature                21.8
# precipitation              42.8
# soil_type                  None
# percentage_tot_prec    0.000782
# precipitation_rank          680
# temp_normalize         0.253333
# Name: 997, dtype: object
# farm_name              Farm 423
# farm_lon                -102.58
# farm_lat                   51.0
# temperature                20.0
# precipitation              42.5
# soil_type                  None
# percentage_tot_prec    0.000777
# precipitation_rank          686
# temp_normalize         0.133333
# Name: 422, dtype: object
# farm_name              Farm 460
# farm_lon                -100.29
# farm_lat                  51.63
# temperature                25.2
# precipitation              42.4
# soil_type                  None
# percentage_tot_prec    0.000775
# precipitation_rank          689
# temp_normalize             0.48
# Name: 459, dtype: object
# farm_name               Farm 80
# farm_lon                -103.28
# farm_lat                  51.04
# temperature                27.5
# precipitation              42.3
# soil_type                  None
# percentage_tot_prec    0.000773
# precipitation_rank          691
# temp_normalize         0.633333
# Name: 79, dtype: object
# farm_name               Farm 68
# farm_lon                -101.56
# farm_lat                  51.96
# temperature                25.4
# precipitation              41.9
# soil_type                  None
# percentage_tot_prec    0.000766
# precipitation_rank          696
# temp_normalize         0.493333
# Name: 67, dtype: object
# farm_name              Farm 170
# farm_lon                 -102.1
# farm_lat                  51.95
# temperature                30.1
# precipitation              40.8
# soil_type                  None
# ...
# Name: 401, dtype: object
# farm_name              Farm 267
# farm_lon                -101.24
# farm_lat                  50.81
# temperature                27.0
# precipitation              38.3
# soil_type                  None
# percentage_tot_prec      0.0007
# precipitation_rank          744
# temp_normalize              0.6
# Name: 266, dtype: object
# farm_name              Farm 561
# farm_lon                -102.74
# farm_lat                  50.17
# temperature                21.2
# precipitation              37.8
# soil_type                  None
# percentage_tot_prec    0.000691
# precipitation_rank          751
# temp_normalize         0.213333
# Name: 560, dtype: object
# farm_name              Farm 231
# farm_lon                -100.71
# farm_lat                  51.87
# temperature                29.8
# precipitation              37.5
# soil_type                  None
# percentage_tot_prec    0.000685
# precipitation_rank          755
# temp_normalize         0.786667
# Name: 230, dtype: object
# farm_name              Farm 393
# farm_lon                -103.65
# farm_lat                  50.87
# temperature                20.4
# precipitation              37.0
# soil_type                  None
# percentage_tot_prec    0.000676
# precipitation_rank          766
# temp_normalize             0.16
# Name: 392, dtype: object
# farm_name              Farm 880
# farm_lon                -100.17
# farm_lat                  51.13
# temperature                26.2
# precipitation              36.9
# soil_type                  None
# percentage_tot_prec    0.000674
# precipitation_rank          769
# temp_normalize         0.546667
# Name: 879, dtype: object
# farm_name              Farm 421
# farm_lon                -104.44
# farm_lat                  50.83
# temperature                31.2
# precipitation              36.8
# soil_type                  None
# percentage_tot_prec    0.000673
# precipitation_rank          772
# temp_normalize             0.88
# Name: 420, dtype: object
# farm_name              Farm 347
# farm_lon                -102.03
# farm_lat                  50.49
# temperature                20.8
# precipitation              36.6
# soil_type                  None
# percentage_tot_prec    0.000669
# precipitation_rank          775
# temp_normalize         0.186667
# Name: 346, dtype: object
# farm_name              Farm 552
# farm_lon                 -103.9
# farm_lat                  51.67
# temperature                31.5
# precipitation              36.1
# soil_type                  None
# percentage_tot_prec     0.00066
# precipitation_rank          783
# temp_normalize              0.9
# Name: 551, dtype: object
# farm_name              Farm 864
# farm_lon                -100.47
# farm_lat                  50.99
# temperature                26.6
# precipitation              36.1
# soil_type                  None
# percentage_tot_prec     0.00066
# precipitation_rank          783
# temp_normalize         0.573333
# Name: 863, dtype: object
# farm_name               Farm 24
# farm_lon                -102.32
# farm_lat                  51.27
# temperature                22.0
# precipitation              36.1
# soil_type                  None
# percentage_tot_prec     0.00066
# precipitation_rank          783
# temp_normalize         0.266667
# Name: 23, dtype: object
# farm_name              Farm 169
# farm_lon                 -101.7
# farm_lat                  50.76
# temperature                22.8
# precipitation              34.9
# soil_type                  None
# percentage_tot_prec    0.000638
# precipitation_rank          794
# temp_normalize             0.32
# Name: 168, dtype: object
# farm_name              Farm 431
# farm_lon                -101.63
# farm_lat                  51.95
# temperature                19.9
# precipitation              32.9
# soil_type                  None
# percentage_tot_prec    0.000601
# precipitation_rank          819
# temp_normalize         0.126667
# Name: 430, dtype: object
# farm_name              Farm 140
# farm_lon                -103.27
# farm_lat                  51.65
# temperature                27.2
# precipitation              32.6
# soil_type                  None
# percentage_tot_prec    0.000596
# precipitation_rank          829
# temp_normalize         0.613333
# Name: 139, dtype: object
# farm_name              Farm 102
# farm_lon                 -101.1
# farm_lat                  51.84
# temperature                25.8
# precipitation              32.6
# soil_type                  None
# percentage_tot_prec    0.000596
# precipitation_rank          829
# temp_normalize             0.52
# Name: 101, dtype: object
# farm_name              Farm 707
# farm_lon                -103.25
# farm_lat                  51.03
# temperature                32.1
# precipitation              32.0
# soil_type                  None
# percentage_tot_prec    0.000585
# precipitation_rank          837
# temp_normalize             0.94
# Name: 706, dtype: object
# farm_name               Farm 72
# farm_lon                -101.71
# farm_lat                  51.78
# temperature                28.1
# precipitation              31.6
# soil_type                  None
# percentage_tot_prec    0.000578
# precipitation_rank          839
# temp_normalize         0.673333
# Name: 71, dtype: object
# farm_name              Farm 229
# farm_lon                 -103.5
# farm_lat                  50.32
# temperature                22.3
# precipitation              30.9
# soil_type                  None
# percentage_tot_prec    0.000565
# precipitation_rank          851
# temp_normalize         0.286667
# Name: 228, dtype: object
# farm_name              Farm 175
# farm_lon                -101.75
# farm_lat                   51.2
# temperature                25.8
# precipitation              30.9
# soil_type                  None
# percentage_tot_prec    0.000565
# precipitation_rank          851
# temp_normalize             0.52
# Name: 174, dtype: object
# farm_name              Farm 248
# farm_lon                -104.45
# farm_lat                  51.54
# temperature                19.5
# precipitation              30.7
# soil_type                  None
# percentage_tot_prec    0.000561
# precipitation_rank          854
# temp_normalize              0.1
# Name: 247, dtype: object
# farm_name              Farm 875
# farm_lon                -100.75
# farm_lat                  50.67
# temperature                30.5
# precipitation              29.9
# soil_type                  None
# percentage_tot_prec    0.000547
# precipitation_rank          862
# temp_normalize         0.833333
# Name: 874, dtype: object
# farm_name              Farm 935
# farm_lon                -104.23
# farm_lat                   50.7
# temperature                29.0
# precipitation              29.7
# soil_type                  None
# percentage_tot_prec    0.000543
# precipitation_rank          863
# temp_normalize         0.733333
# Name: 934, dtype: object
# farm_name              Farm 799
# farm_lon                -101.49
# farm_lat                  50.74
# temperature                30.7
# precipitation              29.7
# soil_type                  None
# percentage_tot_prec    0.000543
# precipitation_rank          863
# temp_normalize         0.846667
# Name: 798, dtype: object
# farm_name              Farm 547
# farm_lon                -101.04
# farm_lat                  50.98
# temperature                28.8
# precipitation              29.0
# soil_type                  None
# percentage_tot_prec     0.00053
# precipitation_rank          867
# temp_normalize             0.72
# Name: 546, dtype: object
# farm_name              Farm 600
# farm_lon                -100.43
# farm_lat                   51.1
# temperature                28.7
# precipitation              28.9
# soil_type                  None
# percentage_tot_prec    0.000528
# precipitation_rank          869
# temp_normalize         0.713333
# Name: 599, dtype: object
# farm_name               Farm 83
# farm_lon                -101.74
# farm_lat                  51.66
# temperature                21.7
# precipitation              28.5
# soil_type                  None
# percentage_tot_prec    0.000521
# precipitation_rank          877
# temp_normalize         0.246667
# Name: 82, dtype: object
# farm_name              Farm 163
# farm_lon                -100.45
# farm_lat                  50.95
# temperature                23.0
# precipitation              28.3
# soil_type                  None
# percentage_tot_prec    0.000517
# precipitation_rank          880
# temp_normalize         0.333333
# Name: 162, dtype: object
# farm_name              Farm 251
# farm_lon                -102.04
# farm_lat                  50.76
# temperature                32.4
# precipitation              28.2
# soil_type                  None
# percentage_tot_prec    0.000515
# precipitation_rank          881
# temp_normalize             0.96
# Name: 250, dtype: object
# farm_name              Farm 581
# farm_lon                -101.25
# farm_lat                  51.16
# temperature                31.0
# precipitation              27.9
# soil_type                  None
# percentage_tot_prec     0.00051
# precipitation_rank          888
# temp_normalize         0.866667
# Name: 580, dtype: object
# farm_name              Farm 968
# farm_lon                -102.74
# farm_lat                   51.6
# temperature                31.8
# precipitation              26.3
# soil_type                  None
# percentage_tot_prec    0.000481
# precipitation_rank          910
# temp_normalize             0.92
# Name: 967, dtype: object
# farm_name              Farm 754
# farm_lon                -101.17
# farm_lat                  51.21
# temperature                25.0
# precipitation              26.2
# soil_type                  None
# percentage_tot_prec    0.000479
# precipitation_rank          912
# temp_normalize         0.466667
# Name: 753, dtype: object
# farm_name               Farm 45
# farm_lon                -102.68
# farm_lat                  51.79
# temperature                25.4
# precipitation              26.2
# soil_type                  None
# percentage_tot_prec    0.000479
# precipitation_rank          912
# temp_normalize         0.493333
# Name: 44, dtype: object
# farm_name              Farm 996
# farm_lon                -104.24
# farm_lat                  51.61
# temperature                19.1
# precipitation              25.8
# soil_type                  None
# percentage_tot_prec    0.000472
# precipitation_rank          918
# temp_normalize         0.073333
# Name: 995, dtype: object
# farm_name              Farm 285
# farm_lon                -100.99
# farm_lat                  50.01
# temperature                29.2
# precipitation              25.4
# soil_type                  None
# percentage_tot_prec    0.000464
# precipitation_rank          924
# temp_normalize         0.746667
# Name: 284, dtype: object
# farm_name              Farm 353
# farm_lon                -103.33
# farm_lat                  50.68
# temperature                21.2
# precipitation              24.7
# soil_type                  None
# percentage_tot_prec    0.000451
# precipitation_rank          933
# temp_normalize         0.213333
# Name: 352, dtype: object
# farm_name              Farm 206
# farm_lon                -101.79
# farm_lat                  51.29
# temperature                23.1
# precipitation              24.3
# soil_type                  None
# percentage_tot_prec    0.000444
# precipitation_rank          935
# temp_normalize             0.34
# Name: 205, dtype: object
# farm_name              Farm 668
# farm_lon                -102.44
# farm_lat                  51.04
# temperature                18.8
# precipitation              23.9
# soil_type                  None
# percentage_tot_prec    0.000437
# precipitation_rank          938
# temp_normalize         0.053333
# Name: 667, dtype: object
# farm_name              Farm 495
# farm_lon                -103.94
# farm_lat                  51.25
# temperature                24.2
# precipitation              23.9
# soil_type                  None
# percentage_tot_prec    0.000437
# precipitation_rank          938
# temp_normalize         0.413333
# Name: 494, dtype: object
# farm_name              Farm 602
# farm_lon                -104.23
# farm_lat                  51.47
# temperature                20.1
# precipitation              23.7
# soil_type                  None
# percentage_tot_prec    0.000433
# precipitation_rank          943
# temp_normalize             0.14
# Name: 601, dtype: object
# farm_name              Farm 100
# farm_lon                -102.77
# farm_lat                  50.37
# temperature                30.4
# precipitation              23.5
# soil_type                  None
# percentage_tot_prec     0.00043
# precipitation_rank          950
# temp_normalize         0.826667
# Name: 99, dtype: object
# farm_name              Farm 15
# farm_lon               -103.42
# farm_lat                 51.52
# temperature               28.2
# precipitation             23.5
# soil_type                 None
# percentage_tot_prec    0.00043
# precipitation_rank         950
# temp_normalize            0.68
# Name: 14, dtype: object
# farm_name              Farm 589
# farm_lon                -101.14
# farm_lat                  51.81
# temperature                29.1
# precipitation              23.5
# soil_type                  None
# percentage_tot_prec     0.00043
# precipitation_rank          950
# temp_normalize             0.74
# Name: 588, dtype: object
# farm_name              Farm 706
# farm_lon                -104.03
# farm_lat                  50.49
# temperature                24.8
# precipitation              23.5
# soil_type                  None
# percentage_tot_prec     0.00043
# precipitation_rank          950
# temp_normalize         0.453333
# Name: 705, dtype: object
# farm_name              Farm 390
# farm_lon                -104.53
# farm_lat                  50.32
# temperature                20.4
# precipitation              23.4
# soil_type                  None
# percentage_tot_prec    0.000428
# precipitation_rank          953
# temp_normalize             0.16
# Name: 389, dtype: object
# farm_name              Farm 563
# farm_lon                -101.03
# farm_lat                  50.27
# temperature                32.9
# precipitation              23.0
# soil_type                  None
# percentage_tot_prec     0.00042
# precipitation_rank          957
# temp_normalize         0.993333
# Name: 562, dtype: object
# farm_name              Farm 812
# farm_lon                -104.97
# farm_lat                  51.19
# temperature                32.1
# precipitation              22.8
# soil_type                  None
# percentage_tot_prec    0.000417
# precipitation_rank          960
# temp_normalize             0.94
# Name: 811, dtype: object
# farm_name              Farm 567
# farm_lon                -103.99
# farm_lat                   51.2
# temperature                20.8
# precipitation              22.7
# soil_type                  None
# percentage_tot_prec    0.000415
# precipitation_rank          961
# temp_normalize         0.186667
# Name: 566, dtype: object
# farm_name              Farm 927
# farm_lon                -101.94
# farm_lat                  51.82
# temperature                27.2
# precipitation              22.4
# soil_type                  None
# percentage_tot_prec    0.000409
# precipitation_rank          964
# temp_normalize         0.613333
# Name: 926, dtype: object
# farm_name               Farm 58
# farm_lon                -102.06
# farm_lat                  51.63
# temperature                29.0
# precipitation              22.3
# soil_type                  None
# percentage_tot_prec    0.000408
# precipitation_rank          966
# temp_normalize         0.733333
# Name: 57, dtype: object
# farm_name              Farm 658
# farm_lon                -101.25
# farm_lat                   51.5
# temperature                22.6
# precipitation              21.6
# soil_type                  None
# percentage_tot_prec    0.000395
# precipitation_rank          977
# temp_normalize         0.306667
# Name: 657, dtype: object
# farm_name              Farm 636
# farm_lon                -102.38
# farm_lat                  51.17
# temperature                26.4
# precipitation              21.5
# soil_type                  None
# percentage_tot_prec    0.000393
# precipitation_rank          981
# temp_normalize             0.56
# Name: 635, dtype: object
# farm_name              Farm 769
# farm_lon                -104.35
# farm_lat                  51.47
# temperature                23.3
# precipitation              21.4
# soil_type                  None
# percentage_tot_prec    0.000391
# precipitation_rank          983
# temp_normalize         0.353333
# Name: 768, dtype: object

# %% [markdown]
# 13. Find outliers if there is any how would you handle them

# %%
## Your code here down
# Here is how i would exclude outliers for temperate
# calculate interquartile for temperate
Q1 = df['temperature'].quantile(0.35)
Q3 = df['temperature'].quantile(0.75)
IQR = Q3 - Q1

# identify outliers
threshold = 1.5
outliers = df[(df['temperature'] < Q1 - threshold * IQR) | (df['temperature'] > Q3 + threshold * IQR)]
outliers
## Your code here up
# Out:
# Empty DataFrame
# Columns: [farm_name, farm_lon, farm_lat, temperature, precipitation, soil_type, percentage_tot_prec, precipitation_rank, temp_normalize]
# Index: []

# %% [markdown]
# 14. Find descriptive statistics for relavant columns and plot them by using bars.

# %%
## Your code here down
import matplotlib.pyplot as plt

df.boxplot(column=['precipitation'])
## Your code here up
# Out:
# <Axes: >

# %%
df.boxplot(column=['temperature'])
plt.show()

# %% [markdown]
# 15. Plot the distribution of relevant columns.

# %%
## Your code here down

(df.hist(bins=10,figsize=(10,10)))
plt.show()

## Your code here up
